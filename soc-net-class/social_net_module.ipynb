# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from datetime import datetime
import warnings
# %matplotlib inline

# %%
import os
os.listdir()
# Out:
# ['node_cmap.png',
#  'social_net_module.ipynb',
#  '.DS_Store',
#  'edge.txt',
#  'learn_graphs_sna_3.ipynb',
#  'path.gpickle',
#  '.gitignore',
#  'learn_graphs_sna_1.ipynb',
#  'Synthetic Social Network.pkl',
#  '.ipynb_checkpoints',
#  'learn_graphs_sna_2.ipynb']

# %%
# deprecated function, will not work unless downgrade Networkx to 2.3.0
social = nx.read_gpickle('Synthetic Social Network.pkl')

plt.figure(figsize = (10,7))

nx.draw_networkx(social)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-60d65910bde4> in <module>
#       4 plt.figure(figsize = (10,7))
#       5
# ----> 6 nx.draw_networkx(social)
#
# /usr/local/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     270
#     271     if pos is None:
# --> 272         pos = nx.drawing.spring_layout(G)  # default to spring layout
#     273
#     274     node_collection = draw_networkx_nodes(G, pos, **kwds)
#
# </usr/local/anaconda3/lib/python3.7/site-packages/decorator.py:decorator-gen-829> in fruchterman_reingold_layout(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed)
#
# /usr/local/anaconda3/lib/python3.7/site-packages/networkx/utils/decorators.py in _random_state(func, *args, **kwargs)
#     403         new_args = list(args)
# ...

# %%
#list of individuals in the graph and length
social.nodes()
len(social.nodes)

# %%
#list of edges and total edges - number of relationships in network - deprecated code
social.edges()
len(social.edges())

# %%
#find most import node in network - deprecated code
social.degree()

# %% [markdown]
# ### Section 22 Subgraphs

# %%
er = nx.erdos_renyi_graph(100, .15)
nx.draw(er, with_labels = True)

# %%
sub = nx.subgraph(er, range(0,40,2)) #subgraph of even values between 0 and 39
nx.draw(sub, node_color = 'firebrick', with_labels = True)

# %% [markdown]
# ### Find number of triangles in a graph

# %%
cg = nx.complete_graph(5) #click graph = all nodes are connected to all other nodes

nx.draw(cg, with_labels = True)

# %%
# print number of triangles at node 0
print(nx.triangles(cg, 0))
# Out:
# 6

# %%
#print the number of tiangles in the graph
print(nx.triangles(cg))
# Out:
# {0: 6, 1: 6, 2: 6, 3: 6, 4: 6}

# %%
#print list of triangles at nodes 0 & 1
print(nx.triangles(cg,(0,1)).values())
# Out:
# dict_values([6, 6])
